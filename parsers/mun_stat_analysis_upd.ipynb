# %% [markdown]
# Ссылка на БД: https://tochno.st/datasets/bdmo

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Население (данные 2023 года)
#
# Файл: data_Y48112015_year2023_112_v20241111

# %%
# Площадь каждого округа в гектарах (спарсил ручками)

districts_area = {
    # центральный
    "Арбат": 288,
    "Басманный": 837,
    "Замоскворечье": 495,
    "Красносельский": 496,
    "Мещанский": 576,
    "Пресненский": 1185,
    "Таганский": 801,
    "Тверской": 727,
    "Хамовники": 1192,
    "Якиманка": 480,

    # северный
    "Аэропорт": 458,
    "Беговой": 556,
    "Бескудниковский": 330,
    "Войковский": 661,
    "Восточное Дегунино": 377,
    "Головинский": 893,
    "Дмитровский": 729,
    "Западное Дегунино": 753,
    "Коптево": 538,
    "Левобережный": 646,
    "Молжаниновский": 2178,
    "Савеловский": 270,
    "Сокол": 372,
    "Тимирязевский": 1043,
    "Ховрино": 573,
    "Хорошевский": 988,

    # северно-восточный
    "Алексеевский": 529,
    "Алтуфьевский": 325,
    "Бабушкинский": 507,
    "Бибирево": 645,
    "Бутырский": 504,
    "Лианозово": 579,
    "Лосиноостровский": 554,
    "Марфино": 226,
    "Марьина роща": 468,
    "Останкинский": 1246,
    "Отрадное": 1016,
    "Ростокино": 354,
    "Свиблово": 441,
    "Северное Медведково": 566,
    "Южное Медведково": 1029,
    "Ярославский": 387,
    "Северный": 1500,

    # восточный
    "Богородское": 865,
    "Вешняки": 1067,
    "Восточное Измайлово": 385,
    "Восточный": 320,
    "Гольяново": 1499,
    "Ивановское": 1017,
    "Измайлово": 1524,
    "Косино-Ухтомский": 1506,
    "Метрогородок": 2757,
    "Новогиреево": 446,
    "Новокосино": 360,
    "Перово": 973,
    "Преображенское": 562,
    "Северное Измайлово": 420,
    "Соколиная гора": 784,
    "Сокольники": 1028,

    # юго-восточный
    "Выхино-Жулебино": 1497,
    "Капотня": 806,
    "Кузьминки": 815,
    "Лефортово": 906,
    "Люблино": 1741,
    "Марьино": 1198,
    "Некрасовка": 1147,
    "Нижегородский": 753,
    "Печатники": 1789,
    "Рязанский": 649,
    "Текстильщики": 591,
    "Южнопортовый": 453,

    # южный
    "Бирюлево Восточное": 1477.2,
    "Бирюлево Западное": 850.64,
    "Братеево": 763.0,
    "Даниловский": 1259.6,
    "Донской": 572.85,
    "Зябликово": 437.95,
    "Москворечье-Сабурово": 930.15,
    "Нагатино-Садовники": 817.0,
    "Нагатинский затон": 979.5,
    "Нагорный": 541.61,
    "Орехово-Борисово Северное": 767.16,
    "Орехово-Борисово Южное": 694.26,
    "Царицыно": 843.44,
    "Чертаново Северное": 540.16,
    "Чертаново Центральное": 651.59,
    "Чертаново Южное": 938.0,

    # юго-западный
    "Академический": 583.44,
    "Гагаринский": 549.91,
    "Зюзино": 545.04,
    "Коньково": 717.91,
    "Котловка": 394.41,
    "Ломоносовский": 333.75,
    "Обручевский": 610.94,
    "Северное Бутово": 913.38,
    "Теплый Стан": 750.0,
    "Черемушки": 551.86,
    "Южное Бутово": 2553.74,
    "Ясенево": 2536.65,

    # западный
    "Дорогомилово": 795.0,
    "Крылатское": 1204.46,
    "Кунцево": 1656.48,
    "Можайский": 1072.6,
    "Ново-Переделкино": 847.82,
    "Очаково-Матвеевское": 1754.36,
    "Проспект Вернадского": 465.14,
    "Раменки": 1853.71,
    "Солнцево": 1129.0,
    "Тропарево-Никулино": 1126.66,
    "Филевский парк": 962.43,
    "Фили-Давыдково": 695.71,

    # северо-западный
    "Куркино": 804,
    "Митино": 1266,
    "Покровское-Стрешнево": 1290,
    "Северное Тушино": 940,
    "Строгино": 1684,
    "Хорошево-Мневники": 1781,
    "Щукино": 768,
    "Южное Тушино": 794,

    # зеленоградский
    "Матушкино": 503.1,
    "Савелки": 812.2,
    "Старое Крюково": 380.5,
    "Силино": 1039.63,
    "Крюково": 1125.0,

    # троицкий (границы 2012-2024)
    "Бекасово": 21096.56,
    "Вороновское": 51392.88,
    "Краснопахорское": 25157.90,
    "Троицк": 9851.92,
    "Киевский": 6009,
    "Кленовское": 11772,
    "Михайлово-Ярцевское": 6461,
    "Новофедоровское": 15080,
    "Первомайское": 11892,
    "Роговское": 17818,
    "Щаповское": 8688,

    # новомосковский (границы 2012-2024)
    "Внуковское": 2559,
    "Внуково": 1691,
    "Воскресенское": 2482,
    "Десеновское": 5300,
    "Московский": 4039,
    "Щербинка": 6530.60,
    "Кокошкино": 900,
    "Марушкинское": 5063,
    '«Мосрентген»': 648,
    "Рязановское": 4048,
    "Сосенское": 6681,
    "Филимонковское": 3572
}

# %%
## Плотность всего населения
## Численность городского населения по полу и возрасту на 1 января текущего года
file_path = "drive/MyDrive/masters/geo-embeddings/popul_age_stats.csv"

df = pd.read_csv(file_path, sep=';')
df.head(2)
# Out:
# <ipython-input-4-784590bf5cbf>:5: DtypeWarning: Columns (14,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep=';')
#    indicator_section_code indicator_section indicator_code  \
# 0                      31         Население      Y48112015
# 1                      31         Население      Y48112015
#
#                                       indicator_name   grup_2 vozr  region_id  \
# 0  Численность городского населения по полу и воз...    Всего    5          1
# 1  Численность городского населения по полу и воз...  Мужчины   26          1
#
#       region_name                                  mun_level  \
# 0  Алтайский край  Муниципальное образование верхнего уровня
# 1  Алтайский край  Муниципальное образование верхнего уровня
#
#                           mun_district  ...       mun_type_oktmo  \
# 0  Муниципальный округ город Славгород  ...  Муниципальный округ
# 1  Муниципальный округ город Славгород  ...  Муниципальный округ
#
#    oktmo_stable                        oktmo_history oktmo_year_from  \
# 0       1539000  Изменен тип и название, Объединение            2023
# 1       1539000  Изменен тип и название, Объединение            2023
#
#   oktmo_year_to  year indicator_value indicator_unit  indicator_period  \
# 0          2025  2023           252.0        Человек       На 1 января
# 1          2025  2023           117.0        Человек       На 1 января
#
#    comment
# 0       CD
# 1       CD
#
# [2 rows x 23 columns]

# %%
# Фильтруем Москву
df = df[df["region_name"] == "Москва"]

# Убираем хвостики у названий
patterns = ['Муниципальный округ ', 'Городской округ ', 'Поселение ']
for pattern in patterns:
        df['mun_district'] = df['mun_district'].str.replace(pattern, '')

# Кол-во муниципалитетов, округов и прочего
mun_num = len(df["mun_district"].unique())

print(f"Москва, 132 муниципалитета и 12 округов: {mun_num}")
# Out:
# Москва, 132 муниципалитета и 12 округов: 147

# %%
# Добавим площадь
df['area'] = df['mun_district'].apply(
    lambda x: districts_area.get(x, None)
    )

# Переведем га в км
df['area'] = df['area'] / 100

# %%
# Меняем категорию, чтобы система видела пожилых (пусть 72)
df["vozr"] = df["vozr"].replace("70 и старше", "72")

df["grup_2"].unique(), df["vozr"].unique()
# Out:
# (array(['Женщины', 'Всего', 'Мужчины'], dtype=object),
#  array(['Всего', '66', '5‒18', '14‒15', '5', '28', '0‒14', '35', '3',
#         '30‒34', '60', '20', '16‒29', '31', '57', '39', '20‒24', '46',
#         '0‒4', '25‒29', 'До 30', '27', '8‒13', '4', '61', '45', '55‒59',
#         'Старше 65', '40‒44', '50‒59', '10‒14', '21', '67', '52', '55',
#         '40', '32', '17', '36', '60‒64', '16', '25', '38', '62', '30',
#         '5‒17', '15‒49', '41', '0‒2', '45‒49', '10', '15', '51', '42', '1',
#         '49', '0‒17', '2', '72', '13', '54', '69', '35‒39', '34', '56',
#         '59', '1‒6', '30‒39', 'Старше трудоспособного возраста', '53', '7',
#         '43', '68', '40‒49', '44', 'Трудоспособный возраст', '8', '18',
#         '19', '50‒54', '22', '33', '60‒65', '11', '14', '47', '65', '50',
#         '3‒5', '23', '6', '5‒9', '63', '16‒17', '12', '65‒69', '37', '24',
#         '9', '48', '29', 'Моложе трудоспособного возраста', '15‒19',
#         '18‒19', '58', '26', '0', '64'], dtype=object))

# %%
df_pop = df[(df["grup_2"] == "Всего") & (df["vozr"] == "Всего")]
df_pop = df_pop.rename(columns={"indicator_value": "population"})
df_pop.head(2)
# Out:
#         indicator_section_code indicator_section indicator_code  \
# 299004                      31         Население      Y48112015
# 299295                      31         Население      Y48112015
#
#                                            indicator_name grup_2   vozr  \
# 299004  Численность городского населения по полу и воз...  Всего  Всего
# 299295  Численность городского населения по полу и воз...  Всего  Всего
#
#         region_id region_name                                  mun_level  \
# 299004         45      Москва                                 Субъект РФ
# 299295         45      Москва  Муниципальное образование верхнего уровня
#
#                                              mun_district  ... oktmo_stable  \
# 299004  Муниципальные образования города Москвы (столи...  ...           CD
# 299295                                        Богородское  ...     45301000
#
#                  oktmo_history oktmo_year_from oktmo_year_to  year  \
# 299004                      CD              CD            CD  2023
# 299295  Изменен тип и название            2010          2013  2023
#
#         population indicator_unit indicator_period  \
# 299004  13104177.0        Человек      На 1 января
# 299295    108657.0        Человек      На 1 января
#
#                                                   comment  area
# 299004  mun_type в исходных данных не соответствует oktmo   NaN
# 299295                                                 CD  8.65
#
# [2 rows x 24 columns]

# %% [markdown]
# ### Плотность всего населения
#
# По муниципальным округам (чел/км2)

# %%
# Плотность всего населения по округам
filtered_data = df[(df["grup_2"] == "Всего") & (df["vozr"] == "Всего")]

filtered_data["pop_dense"] = filtered_data["indicator_value"] / filtered_data["area"]
filtered_data[["mun_district", "indicator_value", "area", "pop_dense"]]
# Out:
# <ipython-input-9-256b7e7c504b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data["pop_dense"] = filtered_data["indicator_value"] / filtered_data["area"]
#                                              mun_district  indicator_value  \
# 299004  Муниципальные образования города Москвы (столи...       13104177.0
# 299295                                        Богородское         108657.0
# 299617                                            Вешняки         119927.0
# 300117                                Восточное Измайлово          73929.0
# 300463                                          Восточный          12906.0
# ...                                                   ...              ...
# 345040                                          Роговское           6478.0
# 345454                                        Рязановское          32215.0
# 345637                                          Сосенское         115545.0
# 346106                                     Филимонковское          16237.0
# 346423                                          Щаповское          13350.0
#
#           area     pop_dense
# 299004     NaN           NaN
# 299295    8.65  12561.502890
# 299617   10.67  11239.643861
# 300117    3.85  19202.337662
# 300463    3.20   4033.125000
# ...        ...           ...
# 345040  178.18     36.356493
# 345454   40.48    795.825099
# 345637   66.81   1729.456668
# 346106   35.72    454.563270
# 346423   86.88    153.660221
#
# [147 rows x 4 columns]

# %%
# Проверка, что захватили все округа
filtered_data[filtered_data["area"].isna()]
# Out:
#         indicator_section_code indicator_section indicator_code  \
# 299004                      31         Население      Y48112015
#
#                                            indicator_name grup_2   vozr  \
# 299004  Численность городского населения по полу и воз...  Всего  Всего
#
#         region_id region_name   mun_level  \
# 299004         45      Москва  Субъект РФ
#
#                                              mun_district  ... oktmo_history  \
# 299004  Муниципальные образования города Москвы (столи...  ...            CD
#
#         oktmo_year_from oktmo_year_to  year indicator_value indicator_unit  \
# 299004               CD            CD  2023      13104177.0        Человек
#
#        indicator_period                                            comment  \
# 299004      На 1 января  mun_type в исходных данных не соответствует oktmo
#
#         area  pop_dense
# 299004   NaN        NaN
#
# [1 rows x 25 columns]

# %%
# Начинаем составлять итоговый датасет
result = filtered_data[["mun_district", "indicator_value", "area", "pop_dense"]].reset_index()
result = result.drop("index", axis=1)

# %% [markdown]
# ### Плотность трудоспособного населения
#
# По муниципальным округам (чел/км2)

# %%
# Плотность трудоспособного населения по округам
filtered_data = df[(df["grup_2"] == "Всего") & (df["vozr"] == "Трудоспособный возраст")]

filtered_data["pop_work_dense"] = filtered_data["indicator_value"] / filtered_data["area"]
filtered_data = filtered_data[["mun_district", "indicator_value", "area", "pop_work_dense"]]
filtered_data
# Out:
# <ipython-input-12-39ba280243eb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data["pop_work_dense"] = filtered_data["indicator_value"] / filtered_data["area"]
#                                              mun_district  indicator_value  \
# 299027  Муниципальные образования города Москвы (столи...        7512670.0
# 299488                                        Богородское          59738.0
# 299825                                            Вешняки          68282.0
# 299969                                Восточное Измайлово          44275.0
# 300421                                          Восточный           7461.0
# ...                                                   ...              ...
# 345234                                          Роговское           3307.0
# 345408                                        Рязановское          18543.0
# 345686                                          Сосенское          65912.0
# 346189                                     Филимонковское           8759.0
# 346470                                          Щаповское           7657.0
#
#           area  pop_work_dense
# 299027     NaN             NaN
# 299488    8.65     6906.127168
# 299825   10.67     6399.437676
# 299969    3.85    11500.000000
# 300421    3.20     2331.562500
# ...        ...             ...
# 345234  178.18       18.559883
# 345408   40.48      458.078063
# 345686   66.81      986.558898
# 346189   35.72      245.212766
# 346470   86.88       88.133057
#
# [147 rows x 4 columns]

# %%
# Продолжаем составлять итоговый датасет
result = pd.merge(result, filtered_data[["mun_district", "pop_work_dense"]], on="mun_district", how="left")
result
# Out:
#                                           mun_district  indicator_value  \
# 0    Муниципальные образования города Москвы (столи...       13104177.0
# 1                                          Богородское         108657.0
# 2                                              Вешняки         119927.0
# 3                                  Восточное Измайлово          73929.0
# 4                                            Восточный          12906.0
# ..                                                 ...              ...
# 142                                          Роговское           6478.0
# 143                                        Рязановское          32215.0
# 144                                          Сосенское         115545.0
# 145                                     Филимонковское          16237.0
# 146                                          Щаповское          13350.0
#
#        area     pop_dense  pop_work_dense
# 0       NaN           NaN             NaN
# 1      8.65  12561.502890     6906.127168
# 2     10.67  11239.643861     6399.437676
# 3      3.85  19202.337662    11500.000000
# 4      3.20   4033.125000     2331.562500
# ..      ...           ...             ...
# 142  178.18     36.356493       18.559883
# 143   40.48    795.825099      458.078063
# 144   66.81   1729.456668      986.558898
# 145   35.72    454.563270      245.212766
# 146   86.88    153.660221       88.133057
#
# [147 rows x 5 columns]

# %% [markdown]
# ### Плотность детей (ниже труд. возр)
#
# По муниципальным округам (чел/км2)

# %%
# Плотность детей по округам
filtered_data = df[(df["grup_2"] == "Всего") & (df["vozr"] == "Моложе трудоспособного возраста")]

filtered_data["pop_child_dense"] = filtered_data["indicator_value"] / filtered_data["area"]
filtered_data = filtered_data[["mun_district", "indicator_value", "area", "pop_child_dense"]]
filtered_data
# Out:
# <ipython-input-14-e7e4951d18a8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data["pop_child_dense"] = filtered_data["indicator_value"] / filtered_data["area"]
#                                              mun_district  indicator_value  \
# 299129  Муниципальные образования города Москвы (столи...        2073639.0
# 299470                                        Богородское          17270.0
# 299576                                            Вешняки          16646.0
# 300067                                Восточное Измайлово          11980.0
# 300373                                          Восточный           1663.0
# ...                                                   ...              ...
# 345030                                          Роговское           1112.0
# 345350                                        Рязановское           5593.0
# 345748                                          Сосенское          26649.0
# 346001                                     Филимонковское           3571.0
# 346333                                          Щаповское           1513.0
#
#           area  pop_child_dense
# 299129     NaN              NaN
# 299470    8.65      1996.531792
# 299576   10.67      1560.074977
# 300067    3.85      3111.688312
# 300373    3.20       519.687500
# ...        ...              ...
# 345030  178.18         6.240880
# 345350   40.48       138.166996
# 345748   66.81       398.877414
# 346001   35.72        99.972004
# 346333   86.88        17.414825
#
# [147 rows x 4 columns]

# %%
# Продолжаем составлять итоговый датасет
result = pd.merge(result, filtered_data[["mun_district", "pop_child_dense"]], on="mun_district", how="left")
result
# Out:
#                                           mun_district  indicator_value  \
# 0    Муниципальные образования города Москвы (столи...       13104177.0
# 1                                          Богородское         108657.0
# 2                                              Вешняки         119927.0
# 3                                  Восточное Измайлово          73929.0
# 4                                            Восточный          12906.0
# ..                                                 ...              ...
# 142                                          Роговское           6478.0
# 143                                        Рязановское          32215.0
# 144                                          Сосенское         115545.0
# 145                                     Филимонковское          16237.0
# 146                                          Щаповское          13350.0
#
#        area     pop_dense  pop_work_dense  pop_child_dense
# 0       NaN           NaN             NaN              NaN
# 1      8.65  12561.502890     6906.127168      1996.531792
# 2     10.67  11239.643861     6399.437676      1560.074977
# 3      3.85  19202.337662    11500.000000      3111.688312
# 4      3.20   4033.125000     2331.562500       519.687500
# ..      ...           ...             ...              ...
# 142  178.18     36.356493       18.559883         6.240880
# 143   40.48    795.825099      458.078063       138.166996
# 144   66.81   1729.456668      986.558898       398.877414
# 145   35.72    454.563270      245.212766        99.972004
# 146   86.88    153.660221       88.133057        17.414825
#
# [147 rows x 6 columns]

# %% [markdown]
# ### Средний возраст
#
# По муниципальным округам

# %%
# Средний возраст
avg_age = {}

filtered_data = df[(df["grup_2"] == "Всего")]
for mun in filtered_data["mun_district"].unique():
    sum = 0
    delim = 0
    mun_data = filtered_data[filtered_data["mun_district"] == mun]
    for _, row in mun_data.iterrows():
        try:
            age_group = int(row["vozr"])
            sum += age_group * row["indicator_value"]
            delim += row["indicator_value"]
        except:
            continue
    avg_age[mun] = sum / delim

# %%
# Продолжаем составлять итоговый датасет
result["avg_age"] = result["mun_district"].apply(lambda x: avg_age[x])
result
# Out:
#                                           mun_district  indicator_value  \
# 0    Муниципальные образования города Москвы (столи...       13104177.0
# 1                                          Богородское         108657.0
# 2                                              Вешняки         119927.0
# 3                                  Восточное Измайлово          73929.0
# 4                                            Восточный          12906.0
# ..                                                 ...              ...
# 142                                          Роговское           6478.0
# 143                                        Рязановское          32215.0
# 144                                          Сосенское         115545.0
# 145                                     Филимонковское          16237.0
# 146                                          Щаповское          13350.0
#
#        area     pop_dense  pop_work_dense  pop_child_dense    avg_age
# 0       NaN           NaN             NaN              NaN  41.300748
# 1      8.65  12561.502890     6906.127168      1996.531792  41.819579
# 2     10.67  11239.643861     6399.437676      1560.074977  43.079131
# 3      3.85  19202.337662    11500.000000      3111.688312  39.658564
# 4      3.20   4033.125000     2331.562500       519.687500  42.835735
# ..      ...           ...             ...              ...        ...
# 142  178.18     36.356493       18.559883         6.240880  43.121179
# 143   40.48    795.825099      458.078063       138.166996  41.049666
# 144   66.81   1729.456668      986.558898       398.877414  36.707015
# 145   35.72    454.563270      245.212766        99.972004  38.732463
# 146   86.88    153.660221       88.133057        17.414825  45.581798
#
# [147 rows x 7 columns]

# %% [markdown]
# ## Розничная торговля и общественное питание
#
# Файл: data_Y48201003_112_v20241111
#
# - Оборот розничной торговли (без субъектов малого предпринимательства) на 1 чел

# %%
## Оборот торговли
file_path = "drive/MyDrive/masters/geo-embeddings/retail_trade_stats.csv"

df = pd.read_csv(file_path)
df.head(2)
# Out:
#    indicator_section_code                          indicator_section  \
# 0                       2  Розничная торговля и общественное питание
# 1                       2  Розничная торговля и общественное питание
#
#   indicator_code                                     indicator_name  \
# 0      Y48201003  Оборот розничной торговли (без субъектов малог...
# 1      Y48201003  Оборот розничной торговли (без субъектов малог...
#
#                                                okved  region_id  \
# 0  Розничная торговля в неспециализированных мага...          1
# 1  Розничная торговля, кроме торговли автотранспо...          1
#
#       region_name                                  mun_level  \
# 0  Алтайский край  Муниципальное образование верхнего уровня
# 1  Алтайский край  Муниципальное образование верхнего уровня
#
#                    mun_district                  municipality  ...  \
# 0  Алейский муниципальный район  Алейский муниципальный район  ...
# 1  Алейский муниципальный район  Алейский муниципальный район  ...
#
#         mun_type_oktmo oktmo_stable  oktmo_history oktmo_year_from  \
# 0  Муниципальный район     01601000  Без изменений            2010
# 1  Муниципальный район     01601000  Без изменений            2010
#
#   oktmo_year_to  year indicator_value  indicator_unit  indicator_period  \
# 0          2025  2011         24822.0   Тысяча рублей   Январь-сентябрь
# 1          2025  2011         24822.0   Тысяча рублей   Январь-сентябрь
#
#   comment
# 0      CD
# 1      CD
#
# [2 rows x 22 columns]

# %%
# Фильтруем Москву, годовой показатель и последний доступный год
df = df[(df["region_name"] == "Москва") &
        (df["indicator_period"] == "Январь-декабрь") &
        (df["year"] == 2016) &
        (df["okved"] == "Всего")]

# Убираем хвостики у названий
patterns = ['Муниципальный округ ', 'Городской округ ', 'Поселение ']
for pattern in patterns:
        df['mun_district'] = df['mun_district'].str.replace(pattern, '')

# Кол-во муниципалитетов, округов и прочего
mun_num = len(df["mun_district"].unique())

print(f"Москва, 132 муниципалитета и 12 округов: {mun_num}")
# Out:
# Москва, 132 муниципалитета и 12 округов: 89

# %% [markdown]
# Очевидно, не хватает большого кол-ва данных, да и сами цифры старые, аж 2016 года, стоит подумать, нужны ли они нам

# %%
df_pop.head(2)
# Out:
#         indicator_section_code indicator_section indicator_code  \
# 299004                      31         Население      Y48112015
# 299295                      31         Население      Y48112015
#
#                                            indicator_name grup_2   vozr  \
# 299004  Численность городского населения по полу и воз...  Всего  Всего
# 299295  Численность городского населения по полу и воз...  Всего  Всего
#
#         region_id region_name                                  mun_level  \
# 299004         45      Москва                                 Субъект РФ
# 299295         45      Москва  Муниципальное образование верхнего уровня
#
#                                              mun_district  ... oktmo_stable  \
# 299004  Муниципальные образования города Москвы (столи...  ...           CD
# 299295                                        Богородское  ...     45301000
#
#                  oktmo_history oktmo_year_from oktmo_year_to  year  \
# 299004                      CD              CD            CD  2023
# 299295  Изменен тип и название            2010          2013  2023
#
#         population indicator_unit indicator_period  \
# 299004  13104177.0        Человек      На 1 января
# 299295    108657.0        Человек      На 1 января
#
#                                                   comment  area
# 299004  mun_type в исходных данных не соответствует oktmo   NaN
# 299295                                                 CD  8.65
#
# [2 rows x 24 columns]

# %%
# Считаем относит. розн. торговлю на 1 чел
df = pd.merge(df, df_pop[["mun_district", "population"]], on='mun_district', how='left')
df["trade_per_pers"] = df["indicator_value"] / df["population"]
df.head(5)
# Out:
#    indicator_section_code                          indicator_section  \
# 0                       2  Розничная торговля и общественное питание
# 1                       2  Розничная торговля и общественное питание
# 2                       2  Розничная торговля и общественное питание
# 3                       2  Розничная торговля и общественное питание
# 4                       2  Розничная торговля и общественное питание
#
#   indicator_code                                     indicator_name  okved  \
# 0      Y48201003  Оборот розничной торговли (без субъектов малог...  Всего
# 1      Y48201003  Оборот розничной торговли (без субъектов малог...  Всего
# 2      Y48201003  Оборот розничной торговли (без субъектов малог...  Всего
# 3      Y48201003  Оборот розничной торговли (без субъектов малог...  Всего
# 4      Y48201003  Оборот розничной торговли (без субъектов малог...  Всего
#
#    region_id region_name                                  mun_level  \
# 0         45      Москва  Муниципальное образование верхнего уровня
# 1         45      Москва  Муниципальное образование верхнего уровня
# 2         45      Москва  Муниципальное образование верхнего уровня
# 3         45      Москва  Муниципальное образование верхнего уровня
# 4         45      Москва  Муниципальное образование верхнего уровня
#
#          mun_district                            municipality  ...  \
# 0         Богородское         Муниципальный округ Богородское  ...
# 1           Гольяново           Муниципальный округ Гольяново  ...
# 2           Измайлово           Муниципальный округ Измайлово  ...
# 3              Перово              Муниципальный округ Перово  ...
# 4  Северное Измайлово  Муниципальный округ Северное Измайлово  ...
#
#             oktmo_history oktmo_year_from oktmo_year_to  year indicator_value  \
# 0  Изменен тип и название            2010          2013  2016        397809.0
# 1  Изменен тип и название            2010          2013  2016      16966173.3
# 2  Изменен тип и название            2010          2013  2016       2890268.9
# 3  Изменен тип и название            2010          2013  2016       1489381.9
# 4  Изменен тип и название            2010          2013  2016        424548.3
#
#   indicator_unit indicator_period  comment  population trade_per_pers
# 0  Тысяча рублей   Январь-декабрь       CD    108657.0       3.661145
# 1  Тысяча рублей   Январь-декабрь       CD    165243.0     102.674082
# 2  Тысяча рублей   Январь-декабрь       CD    107953.0      26.773400
# 3  Тысяча рублей   Январь-декабрь       CD    135315.0      11.006776
# 4  Тысяча рублей   Январь-декабрь       CD     84986.0       4.995509
#
# [5 rows x 24 columns]

# %%
# Продолжаем составлять итоговый датасет
result = pd.merge(result, df[["mun_district", "trade_per_pers"]], on="mun_district", how="left")
result
# Out:
#                                           mun_district  indicator_value  \
# 0    Муниципальные образования города Москвы (столи...       13104177.0
# 1                                          Богородское         108657.0
# 2                                              Вешняки         119927.0
# 3                                  Восточное Измайлово          73929.0
# 4                                            Восточный          12906.0
# ..                                                 ...              ...
# 142                                          Роговское           6478.0
# 143                                        Рязановское          32215.0
# 144                                          Сосенское         115545.0
# 145                                     Филимонковское          16237.0
# 146                                          Щаповское          13350.0
#
#        area     pop_dense  pop_work_dense  pop_child_dense    avg_age  \
# 0       NaN           NaN             NaN              NaN  41.300748
# 1      8.65  12561.502890     6906.127168      1996.531792  41.819579
# 2     10.67  11239.643861     6399.437676      1560.074977  43.079131
# 3      3.85  19202.337662    11500.000000      3111.688312  39.658564
# 4      3.20   4033.125000     2331.562500       519.687500  42.835735
# ..      ...           ...             ...              ...        ...
# 142  178.18     36.356493       18.559883         6.240880  43.121179
# 143   40.48    795.825099      458.078063       138.166996  41.049666
# 144   66.81   1729.456668      986.558898       398.877414  36.707015
# 145   35.72    454.563270      245.212766        99.972004  38.732463
# 146   86.88    153.660221       88.133057        17.414825  45.581798
#
#      trade_per_pers
# 0               NaN
# 1          3.661145
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 142             NaN
# 143             NaN
# 144             NaN
# 145             NaN
# 146             NaN
#
# [147 rows x 8 columns]

# %% [markdown]
# ## Здравоохранение
#
# Файл: data_Y48018103_112_v20241111
#
# - Население / Число больничных коек

# %%
## Кол-во коек
file_path = "drive/MyDrive/masters/geo-embeddings/hosp_beds_stats.csv"

df = pd.read_csv(file_path)
df.head(2)
# Out:
#    indicator_section_code indicator_section indicator_code  \
# 0                      33   Здравоохранение      Y48018103
# 1                      33   Здравоохранение      Y48018103
#
#           indicator_name                                              zdrav  \
# 0  Число больничных коек             Самостоятельные больничные организации
# 1  Число больничных коек  Самостоятельные муниципальные больничные орган...
#
#    region_id     region_name                                  mun_level  \
# 0          1  Алтайский край  Муниципальное образование верхнего уровня
# 1          1  Алтайский край  Муниципальное образование верхнего уровня
#
#                    mun_district                  municipality  ...  \
# 0  Алейский муниципальный район  Алейский муниципальный район  ...
# 1  Алейский муниципальный район  Алейский муниципальный район  ...
#
#         mun_type_oktmo oktmo_stable  oktmo_history oktmo_year_from  \
# 0  Муниципальный район     01601000  Без изменений            2010
# 1  Муниципальный район     01601000  Без изменений            2010
#
#   oktmo_year_to  year indicator_value  indicator_unit  \
# 0          2025  2008            75.0           Койка
# 1          2025  2008            75.0           Койка
#
#              indicator_period comment
# 0  Значение показателя за год      CD
# 1  Значение показателя за год      CD
#
# [2 rows x 22 columns]

# %%
# Фильтруем Москву и последний отчетный год
df = df[(df["region_name"] == "Москва") & (df["year"] == 2012)]

# Убираем хвостики у названий
patterns = ['Муниципальный округ ', 'Городской округ ', 'Поселение ']
for pattern in patterns:
        df['mun_district'] = df['mun_district'].str.replace(pattern, '')

# Кол-во муниципалитетов, округов и прочего
mun_num = len(df["mun_district"].unique())

print(f"Москва, 132 муниципалитета и 12 округов: {mun_num}")
# Out:
# Москва, 132 муниципалитета и 12 округов: 91

# %% [markdown]
# Очевидно, не хватает большого кол-ва данных, да и сами цифры старые, аж 2012 года, стоит подумать, нужны ли они нам

# %%
# Есть разные виды больничек
df["zdrav"].unique()
# Out:
# array(['Самостоятельные больничные организации',
#        'Негосударственные больничные организации',
#        'Больничные отделения в составе ЦРБ и других ЛПО'], dtype=object)

# %%
# Считаем общее кол-во коек во всех больничках
df = df.groupby('mun_district')['indicator_value'].sum()
df = df.reset_index()

# %%
# Считаем относит. розн. торговлю на 1 чел
df = pd.merge(df, df_pop[["mun_district", "population"]], on='mun_district', how='left')
df["pers_per_bed"] = df["population"] / df["indicator_value"]
df.head(5)
# Out:
#     mun_district  indicator_value  population  pers_per_bed
# 0  Академический            830.0    113198.0    136.383133
# 1   Алексеевский            770.0     78502.0    101.950649
# 2          Арбат            562.0     35962.0     63.989324
# 3       Аэропорт           1020.0     81964.0     80.356863
# 4   Бабушкинский           1308.0     68075.0     52.045107

# %%
# Продолжаем составлять итоговый датасет
result = pd.merge(result, df[["mun_district", "pers_per_bed"]], on="mun_district", how="left")
result
# Out:
#                                           mun_district  indicator_value  \
# 0    Муниципальные образования города Москвы (столи...       13104177.0
# 1                                          Богородское         108657.0
# 2                                              Вешняки         119927.0
# 3                                  Восточное Измайлово          73929.0
# 4                                            Восточный          12906.0
# ..                                                 ...              ...
# 142                                          Роговское           6478.0
# 143                                        Рязановское          32215.0
# 144                                          Сосенское         115545.0
# 145                                     Филимонковское          16237.0
# 146                                          Щаповское          13350.0
#
#        area     pop_dense  pop_work_dense  pop_child_dense    avg_age  \
# 0       NaN           NaN             NaN              NaN  41.300748
# 1      8.65  12561.502890     6906.127168      1996.531792  41.819579
# 2     10.67  11239.643861     6399.437676      1560.074977  43.079131
# 3      3.85  19202.337662    11500.000000      3111.688312  39.658564
# 4      3.20   4033.125000     2331.562500       519.687500  42.835735
# ..      ...           ...             ...              ...        ...
# 142  178.18     36.356493       18.559883         6.240880  43.121179
# 143   40.48    795.825099      458.078063       138.166996  41.049666
# 144   66.81   1729.456668      986.558898       398.877414  36.707015
# 145   35.72    454.563270      245.212766        99.972004  38.732463
# 146   86.88    153.660221       88.133057        17.414825  45.581798
#
#      trade_per_pers  pers_per_bed
# 0               NaN           NaN
# 1          3.661145           NaN
# 2               NaN     57.712705
# 3               NaN     18.088818
# 4               NaN    368.742857
# ..              ...           ...
# 142             NaN           NaN
# 143             NaN    495.615385
# 144             NaN   3301.285714
# 145             NaN           NaN
# 146             NaN           NaN
#
# [147 rows x 9 columns]

# %% [markdown]
# ## Деятельность предприятий
#
# - Отгружено товаров собственного производства, выполнено работ и услуг собственными силами (без субъектов малого предпринимательства) - data_Y48401011_112_v20241111
# - Продано товаров несобственного производства (без субъектов малого предпринимательства) - data_Y48201002_112_v20241111
# - Количество организаций по данным государственной регистрации - data_Y49010002_112_v20241111
# - Количество индивидуальных предпринимателей по данным государственной регистрации - data_Y49010003_112_v20241111

# %% [markdown]
# ### Товары собственного производства
#
# Файл: data_Y48401011_112_v20241111

# %%
file_path = "drive/MyDrive/masters/geo-embeddings/self_goods_stats.csv"

df = pd.read_csv(file_path)
df.head(2)
# Out:
#    indicator_section_code         indicator_section indicator_code  \
# 0                      39  Деятельность предприятий      Y48401011
# 1                      39  Деятельность предприятий      Y48401011
#
#                                       indicator_name  \
# 0  Отгружено товаров собственного производства, в...
# 1  Отгружено товаров собственного производства, в...
#
#                                               okved2  region_id  \
# 0  Всего по обследуемым видам экономической деяте...          1
# 1  Всего по обследуемым видам экономической деяте...          1
#
#       region_name                                  mun_level  \
# 0  Алтайский край  Муниципальное образование верхнего уровня
# 1  Алтайский край  Муниципальное образование верхнего уровня
#
#                       mun_district                     municipality  ...  \
# 0  Залесовский муниципальный округ  Залесовский муниципальный округ  ...
# 1  Залесовский муниципальный округ  Залесовский муниципальный округ  ...
#
#         mun_type_oktmo oktmo_stable           oktmo_history oktmo_year_from  \
# 0  Муниципальный округ     01512000  Изменен тип и название            2022
# 1  Муниципальный округ     01512000  Изменен тип и название            2022
#
#   oktmo_year_to  year indicator_value  indicator_unit  indicator_period  \
# 0          2025  2022        244664.8   Тысяча рублей    Январь-декабрь
# 1          2025  2022        127158.5   Тысяча рублей       Январь-июнь
#
#   comment
# 0      CD
# 1      CD
#
# [2 rows x 22 columns]

# %%
# Фильтруем Москву и последний отчетный год
df = df[(df["region_name"] == "Москва")
            & (df["year"] == 2023)
            & (df["okved2"] == "Всего по обследуемым видам экономической деятельности")
            & (df["indicator_period"] == "Январь-декабрь")]

# Убираем хвостики у названий
patterns = ['Муниципальный округ ', 'Городской округ ', 'Поселение ']
for pattern in patterns:
        df['mun_district'] = df['mun_district'].str.replace(pattern, '')

# Кол-во муниципалитетов, округов и прочего
mun_num = len(df["mun_district"].unique())

print(f"Москва, 132 муниципалитета и 12 округов: {mun_num}")
# Out:
# Москва, 132 муниципалитета и 12 округов: 144

# %%
# Готово!
df = df.rename(columns={"indicator_value": "self_goods_sold"})
df.head(2)
# Out:
#        indicator_section_code         indicator_section indicator_code  \
# 55970                      39  Деятельность предприятий      Y48401011
# 55998                      39  Деятельность предприятий      Y48401011
#
#                                           indicator_name  \
# 55970  Отгружено товаров собственного производства, в...
# 55998  Отгружено товаров собственного производства, в...
#
#                                                   okved2  region_id  \
# 55970  Всего по обследуемым видам экономической деяте...         45
# 55998  Всего по обследуемым видам экономической деяте...         45
#
#       region_name                                  mun_level mun_district  \
# 55970      Москва  Муниципальное образование верхнего уровня  Богородское
# 55998      Москва  Муниципальное образование верхнего уровня      Вешняки
#
#                           municipality  ...  \
# 55970  Муниципальный округ Богородское  ...
# 55998      Муниципальный округ Вешняки  ...
#
#                                           mun_type_oktmo oktmo_stable  \
# 55970  Внутригородская территория города федерального...     45301000
# 55998  Внутригородская территория города федерального...     45302000
#
#                 oktmo_history oktmo_year_from oktmo_year_to  year  \
# 55970  Изменен тип и название            2010          2013  2023
# 55998  Изменен тип и название            2010          2013  2023
#
#       self_goods_sold  indicator_unit  indicator_period comment
# 55970      25493879.1   Тысяча рублей    Январь-декабрь      CD
# 55998      22482322.9   Тысяча рублей    Январь-декабрь      CD
#
# [2 rows x 22 columns]

# %%
# Продолжаем составлять итоговый датасет
result = pd.merge(result, df[["mun_district", "self_goods_sold"]], on="mun_district", how="left")
result
# Out:
#                                           mun_district  indicator_value  \
# 0    Муниципальные образования города Москвы (столи...       13104177.0
# 1                                          Богородское         108657.0
# 2                                              Вешняки         119927.0
# 3                                  Восточное Измайлово          73929.0
# 4                                            Восточный          12906.0
# ..                                                 ...              ...
# 142                                          Роговское           6478.0
# 143                                        Рязановское          32215.0
# 144                                          Сосенское         115545.0
# 145                                     Филимонковское          16237.0
# 146                                          Щаповское          13350.0
#
#        area     pop_dense  pop_work_dense  pop_child_dense    avg_age  \
# 0       NaN           NaN             NaN              NaN  41.300748
# 1      8.65  12561.502890     6906.127168      1996.531792  41.819579
# 2     10.67  11239.643861     6399.437676      1560.074977  43.079131
# 3      3.85  19202.337662    11500.000000      3111.688312  39.658564
# 4      3.20   4033.125000     2331.562500       519.687500  42.835735
# ..      ...           ...             ...              ...        ...
# 142  178.18     36.356493       18.559883         6.240880  43.121179
# 143   40.48    795.825099      458.078063       138.166996  41.049666
# 144   66.81   1729.456668      986.558898       398.877414  36.707015
# 145   35.72    454.563270      245.212766        99.972004  38.732463
# 146   86.88    153.660221       88.133057        17.414825  45.581798
#
#      trade_per_pers  pers_per_bed  self_goods_sold
# 0               NaN           NaN              NaN
# 1          3.661145           NaN       25493879.1
# 2               NaN     57.712705       22482322.9
# 3               NaN     18.088818       21708295.2
# 4               NaN    368.742857          69276.7
# ..              ...           ...              ...
# 142             NaN           NaN              NaN
# 143             NaN    495.615385       41010696.3
# 144             NaN   3301.285714       67726829.5
# 145             NaN           NaN         882499.8
# 146             NaN           NaN       13945371.0
#
# [147 rows x 10 columns]

# %% [markdown]
# ### Товары несобственного производства
#
# Файл: data_Y48201002_112_v20241111

# %%
file_path = "drive/MyDrive/masters/geo-embeddings/for_goods_stats.csv"

df = pd.read_csv(file_path)
df.head(2)
# Out:
#    indicator_section_code         indicator_section indicator_code  \
# 0                      39  Деятельность предприятий      Y48201002
# 1                      39  Деятельность предприятий      Y48201002
#
#                                       indicator_name  \
# 0  Продано товаров несобственного производства (б...
# 1  Продано товаров несобственного производства (б...
#
#                                                okved  region_id  \
# 0  Раздел Е Производство и распределение электроэ...          1
# 1  Раздел Е Производство и распределение электроэ...          1
#
#       region_name                                  mun_level  \
# 0  Алтайский край  Муниципальное образование верхнего уровня
# 1  Алтайский край  Муниципальное образование верхнего уровня
#
#                    mun_district                  municipality  ...  \
# 0  Алейский муниципальный район  Алейский муниципальный район  ...
# 1  Алейский муниципальный район  Алейский муниципальный район  ...
#
#         mun_type_oktmo oktmo_stable  oktmo_history oktmo_year_from  \
# 0  Муниципальный район     01601000  Без изменений            2010
# 1  Муниципальный район     01601000  Без изменений            2010
#
#   oktmo_year_to  year indicator_value  indicator_unit  indicator_period  \
# 0          2025  2009        226205.5   Тысяча рублей    Январь-декабрь
# 1          2025  2009         78942.6   Тысяча рублей       Январь-март
#
#   comment
# 0      CD
# 1      CD
#
# [2 rows x 22 columns]

# %%
# Фильтруем Москву и последний отчетный год
df = df[(df["region_name"] == "Москва") &
        (df["okved"] == "Всего") &
        (df["year"] == 2016)]

# Убираем хвостики у названий
patterns = ['Муниципальный округ ', 'Городской округ ', 'Поселение ']
for pattern in patterns:
        df['mun_district'] = df['mun_district'].str.replace(pattern, '')

# Кол-во муниципалитетов, округов и прочего
mun_num = len(df["mun_district"].unique())

print(f"Москва, 132 муниципалитета и 12 округов: {mun_num}")
# Out:
# Москва, 132 муниципалитета и 12 округов: 124
# <ipython-input-34-3416091267e7>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mun_district'] = df['mun_district'].str.replace(pattern, '')

# %%
# Готово!
df = df.rename(columns={"indicator_value": "other_goods_sold"})
df.head(2)
# Out:
#        indicator_section_code         indicator_section indicator_code  \
# 27386                      39  Деятельность предприятий      Y48201002
# 27400                      39  Деятельность предприятий      Y48201002
#
#                                           indicator_name  okved  region_id  \
# 27386  Продано товаров несобственного производства (б...  Всего         45
# 27400  Продано товаров несобственного производства (б...  Всего         45
#
#       region_name                                  mun_level  \
# 27386      Москва  Муниципальное образование верхнего уровня
# 27400      Москва  Муниципальное образование верхнего уровня
#
#               mun_district                             municipality  ...  \
# 27386          Богородское          Муниципальный округ Богородское  ...
# 27400  Восточное Измайлово  Муниципальный округ Восточное Измайлово  ...
#
#                                           mun_type_oktmo oktmo_stable  \
# 27386  Внутригородская территория города федерального...     45301000
# 27400  Внутригородская территория города федерального...     45303000
#
#                 oktmo_history oktmo_year_from oktmo_year_to  year  \
# 27386  Изменен тип и название            2010          2013  2016
# 27400  Изменен тип и название            2010          2013  2016
#
#       other_goods_sold  indicator_unit  indicator_period comment
# 27386        2755713.6   Тысяча рублей    Январь-декабрь      CD
# 27400        7229392.4   Тысяча рублей    Январь-декабрь      CD
#
# [2 rows x 22 columns]

# %%
# Продолжаем составлять итоговый датасет
result = pd.merge(result, df[["mun_district", "other_goods_sold"]], on="mun_district", how="left")
result
# Out:
#                                           mun_district  indicator_value  \
# 0    Муниципальные образования города Москвы (столи...       13104177.0
# 1                                          Богородское         108657.0
# 2                                              Вешняки         119927.0
# 3                                  Восточное Измайлово          73929.0
# 4                                            Восточный          12906.0
# ..                                                 ...              ...
# 142                                          Роговское           6478.0
# 143                                        Рязановское          32215.0
# 144                                          Сосенское         115545.0
# 145                                     Филимонковское          16237.0
# 146                                          Щаповское          13350.0
#
#        area     pop_dense  pop_work_dense  pop_child_dense    avg_age  \
# 0       NaN           NaN             NaN              NaN  41.300748
# 1      8.65  12561.502890     6906.127168      1996.531792  41.819579
# 2     10.67  11239.643861     6399.437676      1560.074977  43.079131
# 3      3.85  19202.337662    11500.000000      3111.688312  39.658564
# 4      3.20   4033.125000     2331.562500       519.687500  42.835735
# ..      ...           ...             ...              ...        ...
# 142  178.18     36.356493       18.559883         6.240880  43.121179
# 143   40.48    795.825099      458.078063       138.166996  41.049666
# 144   66.81   1729.456668      986.558898       398.877414  36.707015
# 145   35.72    454.563270      245.212766        99.972004  38.732463
# 146   86.88    153.660221       88.133057        17.414825  45.581798
#
#      trade_per_pers  pers_per_bed  self_goods_sold  other_goods_sold
# 0               NaN           NaN              NaN               NaN
# 1          3.661145           NaN       25493879.1         2755713.6
# 2               NaN     57.712705       22482322.9               NaN
# 3               NaN     18.088818       21708295.2         7229392.4
# 4               NaN    368.742857          69276.7               NaN
# ..              ...           ...              ...               ...
# 142             NaN           NaN              NaN               NaN
# 143             NaN    495.615385       41010696.3         9959747.0
# 144             NaN   3301.285714       67726829.5       112169075.1
# 145             NaN           NaN         882499.8               NaN
# 146             NaN           NaN       13945371.0               NaN
#
# [147 rows x 11 columns]

# %% [markdown]
# ### Количество организаций
#
# Файл: data_Y49010002_112_v20241111

# %%
file_path = "drive/MyDrive/masters/geo-embeddings/org_num_stats.csv"

df = pd.read_csv(file_path)
df.head(2)
# Out:
#    indicator_section_code         indicator_section indicator_code  \
# 0                      39  Деятельность предприятий      Y49010003
# 1                      39  Деятельность предприятий      Y49010003
#
#                                       indicator_name  region_id  \
# 0  Количество индивидуальных предпринимателей по ...          1
# 1  Количество индивидуальных предпринимателей по ...          1
#
#       region_name                                  mun_level  \
# 0  Алтайский край  Муниципальное образование верхнего уровня
# 1  Алтайский край  Муниципальное образование верхнего уровня
#
#                           mun_district                         municipality  \
# 0      Залесовский муниципальный округ      Залесовский муниципальный округ
# 1  Муниципальный округ город Славгород  Муниципальный округ город Славгород
#
#      oktmo  ...       mun_type_oktmo oktmo_stable  \
# 0  1512000  ...  Муниципальный округ     01512000
# 1  1539000  ...  Муниципальный округ     01539000
#
#                          oktmo_history oktmo_year_from oktmo_year_to  year  \
# 0               Изменен тип и название            2022          2025  2024
# 1  Изменен тип и название, Объединение            2023          2025  2024
#
#    indicator_value  indicator_unit indicator_period comment
# 0              217         Человек      На 1 апреля      CD
# 1              854         Человек      На 1 апреля      CD
#
# [2 rows x 21 columns]

# %%
# Фильтруем Москву
df = df[df["region_name"] == "Москва"]

# Убираем хвостики у названий
patterns = ['Муниципальный округ ', 'Городской округ ', 'Поселение ']
for pattern in patterns:
        df['mun_district'] = df['mun_district'].str.replace(pattern, '')

# Кол-во муниципалитетов, округов и прочего
mun_num = len(df["mun_district"].unique())

print(f"Москва, 132 муниципалитета и 12 округов: {mun_num}")
# Out:
# Москва, 132 муниципалитета и 12 округов: 147
# <ipython-input-38-93006c921cb1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mun_district'] = df['mun_district'].str.replace(pattern, '')

# %%
# Готово!
df = df.rename(columns={"indicator_value": "org_num"})
df.head(2)
# Out:
#       indicator_section_code         indicator_section indicator_code  \
# 6541                      39  Деятельность предприятий      Y49010003
# 6542                      39  Деятельность предприятий      Y49010003
#
#                                          indicator_name  region_id  \
# 6541  Количество индивидуальных предпринимателей по ...         45
# 6542  Количество индивидуальных предпринимателей по ...         45
#
#      region_name                                  mun_level  \
# 6541      Москва                                 Субъект РФ
# 6542      Москва  Муниципальное образование верхнего уровня
#
#                                            mun_district  \
# 6541  Муниципальные образования города Москвы (столи...
# 6542                                        Богородское
#
#                                            municipality     oktmo  ...  \
# 6541  Муниципальные образования города Москвы (столи...  45000000  ...
# 6542                    Муниципальный округ Богородское  45301000  ...
#
#                                          mun_type_oktmo oktmo_stable  \
# 6541                                         Субъект РФ           CD
# 6542  Внутригородская территория города федерального...     45301000
#
#                oktmo_history oktmo_year_from oktmo_year_to  year  org_num  \
# 6541                      CD              CD            CD  2024   448529
# 6542  Изменен тип и название            2010          2013  2024     3810
#
#       indicator_unit indicator_period  \
# 6541         Человек      На 1 апреля
# 6542         Человек      На 1 апреля
#
#                                                 comment
# 6541  mun_type в исходных данных не соответствует oktmo
# 6542                                                 CD
#
# [2 rows x 21 columns]

# %%
# Продолжаем составлять итоговый датасет
result = pd.merge(result, df[["mun_district", "org_num"]], on="mun_district", how="left")
result
# Out:
#                                           mun_district  indicator_value  \
# 0    Муниципальные образования города Москвы (столи...       13104177.0
# 1                                          Богородское         108657.0
# 2                                              Вешняки         119927.0
# 3                                  Восточное Измайлово          73929.0
# 4                                            Восточный          12906.0
# ..                                                 ...              ...
# 142                                          Роговское           6478.0
# 143                                        Рязановское          32215.0
# 144                                          Сосенское         115545.0
# 145                                     Филимонковское          16237.0
# 146                                          Щаповское          13350.0
#
#        area     pop_dense  pop_work_dense  pop_child_dense    avg_age  \
# 0       NaN           NaN             NaN              NaN  41.300748
# 1      8.65  12561.502890     6906.127168      1996.531792  41.819579
# 2     10.67  11239.643861     6399.437676      1560.074977  43.079131
# 3      3.85  19202.337662    11500.000000      3111.688312  39.658564
# 4      3.20   4033.125000     2331.562500       519.687500  42.835735
# ..      ...           ...             ...              ...        ...
# 142  178.18     36.356493       18.559883         6.240880  43.121179
# 143   40.48    795.825099      458.078063       138.166996  41.049666
# 144   66.81   1729.456668      986.558898       398.877414  36.707015
# 145   35.72    454.563270      245.212766        99.972004  38.732463
# 146   86.88    153.660221       88.133057        17.414825  45.581798
#
#      trade_per_pers  pers_per_bed  self_goods_sold  other_goods_sold  org_num
# 0               NaN           NaN              NaN               NaN   448529
# 1          3.661145           NaN       25493879.1         2755713.6     3810
# 2               NaN     57.712705       22482322.9               NaN     3397
# 3               NaN     18.088818       21708295.2         7229392.4     2008
# 4               NaN    368.742857          69276.7               NaN      313
# ..              ...           ...              ...               ...      ...
# 142             NaN           NaN              NaN               NaN      249
# 143             NaN    495.615385       41010696.3         9959747.0     1773
# 144             NaN   3301.285714       67726829.5       112169075.1     8727
# 145             NaN           NaN         882499.8               NaN     1171
# 146             NaN           NaN       13945371.0               NaN      672
#
# [147 rows x 12 columns]

# %% [markdown]
# ### Количество ИП
#
# Файл: data_Y49010003_112_v20241111

# %%
file_path = "drive/MyDrive/masters/geo-embeddings/bus_num_stats.csv"

df = pd.read_csv(file_path)
df.head(2)
# Out:
#    indicator_section_code         indicator_section indicator_code  \
# 0                      39  Деятельность предприятий      Y49010002
# 1                      39  Деятельность предприятий      Y49010002
#
#                                       indicator_name  region_id  \
# 0  Количество организаций по данным государственн...          1
# 1  Количество организаций по данным государственн...          1
#
#       region_name                                  mun_level  \
# 0  Алтайский край  Муниципальное образование верхнего уровня
# 1  Алтайский край  Муниципальное образование верхнего уровня
#
#                           mun_district                         municipality  \
# 0      Залесовский муниципальный округ      Залесовский муниципальный округ
# 1  Муниципальный округ город Славгород  Муниципальный округ город Славгород
#
#      oktmo  ...       mun_type_oktmo oktmo_stable  \
# 0  1512000  ...  Муниципальный округ     01512000
# 1  1539000  ...  Муниципальный округ     01539000
#
#                          oktmo_history oktmo_year_from oktmo_year_to  year  \
# 0               Изменен тип и название            2022          2025  2024
# 1  Изменен тип и название, Объединение            2023          2025  2024
#
#    indicator_value  indicator_unit indicator_period comment
# 0               75         Единица      На 1 апреля      CD
# 1              266         Единица      На 1 апреля      CD
#
# [2 rows x 21 columns]

# %%
# Фильтруем Москву
df = df[df["region_name"] == "Москва"]

# Убираем хвостики у названий
patterns = ['Муниципальный округ ', 'Городской округ ', 'Поселение ']
for pattern in patterns:
        df['mun_district'] = df['mun_district'].str.replace(pattern, '')

# Кол-во муниципалитетов, округов и прочего
mun_num = len(df["mun_district"].unique())

print(f"Москва, 132 муниципалитета и 12 округов: {mun_num}")
# Out:
# Москва, 132 муниципалитета и 12 округов: 147
# <ipython-input-42-93006c921cb1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mun_district'] = df['mun_district'].str.replace(pattern, '')

# %%
# Готово!
df = df.rename(columns={"indicator_value": "entrep_num"})
df.head(2)
# Out:
#       indicator_section_code         indicator_section indicator_code  \
# 6424                      39  Деятельность предприятий      Y49010002
# 6425                      39  Деятельность предприятий      Y49010002
#
#                                          indicator_name  region_id  \
# 6424  Количество организаций по данным государственн...         45
# 6425  Количество организаций по данным государственн...         45
#
#      region_name                                  mun_level  \
# 6424      Москва                                 Субъект РФ
# 6425      Москва  Муниципальное образование верхнего уровня
#
#                                            mun_district  \
# 6424  Муниципальные образования города Москвы (столи...
# 6425                                        Богородское
#
#                                            municipality     oktmo  ...  \
# 6424  Муниципальные образования города Москвы (столи...  45000000  ...
# 6425                    Муниципальный округ Богородское  45301000  ...
#
#                                          mun_type_oktmo oktmo_stable  \
# 6424                                         Субъект РФ           CD
# 6425  Внутригородская территория города федерального...     45301000
#
#                oktmo_history oktmo_year_from oktmo_year_to  year  entrep_num  \
# 6424                      CD              CD            CD  2024      613120
# 6425  Изменен тип и название            2010          2013  2024        4270
#
#       indicator_unit indicator_period  \
# 6424         Единица      На 1 апреля
# 6425         Единица      На 1 апреля
#
#                                                 comment
# 6424  mun_type в исходных данных не соответствует oktmo
# 6425                                                 CD
#
# [2 rows x 21 columns]

# %%
# Продолжаем составлять итоговый датасет
result = pd.merge(result, df[["mun_district", "entrep_num"]], on="mun_district", how="left")
result
# Out:
#                                           mun_district  indicator_value  \
# 0    Муниципальные образования города Москвы (столи...       13104177.0
# 1                                          Богородское         108657.0
# 2                                              Вешняки         119927.0
# 3                                  Восточное Измайлово          73929.0
# 4                                            Восточный          12906.0
# ..                                                 ...              ...
# 142                                          Роговское           6478.0
# 143                                        Рязановское          32215.0
# 144                                          Сосенское         115545.0
# 145                                     Филимонковское          16237.0
# 146                                          Щаповское          13350.0
#
#        area     pop_dense  pop_work_dense  pop_child_dense    avg_age  \
# 0       NaN           NaN             NaN              NaN  41.300748
# 1      8.65  12561.502890     6906.127168      1996.531792  41.819579
# 2     10.67  11239.643861     6399.437676      1560.074977  43.079131
# 3      3.85  19202.337662    11500.000000      3111.688312  39.658564
# 4      3.20   4033.125000     2331.562500       519.687500  42.835735
# ..      ...           ...             ...              ...        ...
# 142  178.18     36.356493       18.559883         6.240880  43.121179
# 143   40.48    795.825099      458.078063       138.166996  41.049666
# 144   66.81   1729.456668      986.558898       398.877414  36.707015
# 145   35.72    454.563270      245.212766        99.972004  38.732463
# 146   86.88    153.660221       88.133057        17.414825  45.581798
#
#      trade_per_pers  pers_per_bed  self_goods_sold  other_goods_sold  org_num  \
# 0               NaN           NaN              NaN               NaN   448529
# 1          3.661145           NaN       25493879.1         2755713.6     3810
# 2               NaN     57.712705       22482322.9               NaN     3397
# 3               NaN     18.088818       21708295.2         7229392.4     2008
# 4               NaN    368.742857          69276.7               NaN      313
# ..              ...           ...              ...               ...      ...
# 142             NaN           NaN              NaN               NaN      249
# 143             NaN    495.615385       41010696.3         9959747.0     1773
# 144             NaN   3301.285714       67726829.5       112169075.1     8727
# 145             NaN           NaN         882499.8               NaN     1171
# 146             NaN           NaN       13945371.0               NaN      672
#
#      entrep_num
# 0        613120
# 1          4270
# 2          1743
# 3          1937
# 4           160
# ..          ...
# 142         120
# 143         598
# 144        7334
# 145         299
# 146         328
#
# [147 rows x 13 columns]

# %% [markdown]
# ## Границы административных районов
#
# Чтобы спроецировать данные на карте - необходимо получить координаты всех муниципальных районов Москвы

# %%
# %%capture
# !pip install osmnx pyrosm
# !apt-get update -qq && apt-get install -y osmium-tool

# %%
# !wget -nc https://download.geofabrik.de/russia/central-fed-district-latest.osm.pbf
# Out:
# --2025-05-31 18:08:41--  https://download.geofabrik.de/russia/central-fed-district-latest.osm.pbf
# Resolving download.geofabrik.de (download.geofabrik.de)... 95.216.245.233, 95.217.45.61, 95.217.63.98, ...
# Connecting to download.geofabrik.de (download.geofabrik.de)|95.216.245.233|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 828479216 (790M) [application/octet-stream]
# Saving to: ‘central-fed-district-latest.osm.pbf’
#
# central-fed-distric 100%[===================>] 790.10M  73.3MB/s    in 11s
#
# 2025-05-31 18:08:53 (71.2 MB/s) - ‘central-fed-district-latest.osm.pbf’ saved [828479216/828479216]

# %%
# from pyrosm import OSM, get_data
import requests
from shapely.geometry import LineString
from shapely.ops import polygonize, unary_union
import json
import matplotlib.pyplot as plt
from pyrosm import OSM

# %%
overpass_url = "https://overpass-api.de/api/interpreter"
query = """
[out:json][timeout:25];
relation["boundary"="administrative"]["admin_level"="4"]["name"="Москва"];
out geom;
"""

resp = requests.get(overpass_url, params={"data": query})
data = resp.json()

# %%
# Создаем список всех полигонов районов
district_polygons = []
for element in data["elements"]:
    if element["type"] == "relation":
        members = element.get("members", [])
        lines = []
        for m in members:
            if m["role"] in ["outer", ""] and "geometry" in m:  # Некоторые роли могут быть пустыми
                coords = [(pt["lon"], pt["lat"]) for pt in m["geometry"]]
                if len(coords) > 1:  # Проверяем, что линия валидна
                    lines.append(LineString(coords))

        if lines:
            try:
                # Пробуем создать полигон из линий
                polygons = list(polygonize(lines))
                if polygons:
                    district_polygon = unary_union(polygons)
                    district_polygons.append({
                        "type": "Feature",
                        "properties": {"name": element["tags"].get("name", "")},
                        "geometry": json.loads(json.dumps(district_polygon.__geo_interface__))
                    })
            except:
                print(f"Ошибка при обработке района {element.get('id')}")

# Сохраняем все районы как FeatureCollection
geojson = {
    "type": "FeatureCollection",
    "features": district_polygons
}

with open("moscow_districts.geojson", "w", encoding="utf-8") as f:
    json.dump(geojson, f, ensure_ascii=False, indent=2)

print("Границы районов сохранены в moscow_districts.geojson")
# Out:
# Границы районов сохранены в moscow_districts.geojson

# %%
# !osmium extract \
    --overwrite \
    --output-format pbf \
    --polygon moscow_districts.geojson \
    central-fed-district-latest.osm.pbf \
    -o moscow-districts.osm.pbf
# Out:
# [======================================================================] 100%

# %%
fp = "moscow-districts.osm.pbf"

osm = OSM(fp)

# Получаем все административные границы
boundaries = osm.get_boundaries()

# %%
print(boundaries.keys()), len(boundaries)
# Out:
# Index(['addr:country', 'name', 'ref', 'website', 'admin_level', 'boundary',
#        'border_type', 'start_date', 'id', 'timestamp', 'version', 'changeset',
#        'geometry', 'tags', 'osm_type'],
#       dtype='object')
# (None, 166)

# %%
# mun_geo.to_csv("mun_geo.csv")
mun_geo = pd.read_csv("mun_geo.csv")

# %%
# mun_geo = boundaries[["name", "geometry"]]
mun_geo = mun_geo.rename(columns={"name": "mun_district"})
mun_geo['mun_district'] = mun_geo['mun_district'].str.replace("ё", 'е')

patterns = [' административный округ', 'городской округ ', 'район ', ' район']
for pattern in patterns:
        mun_geo['mun_district'] = mun_geo['mun_district'].str.replace(pattern, '')

mun_geo.head()
# Out:
#    Unnamed: 0        mun_district  \
# 0           0  Московская область
# 1           1   Калужская область
# 2           2              Москва
# 3           3            Северный
# 4           4              Мытищи
#
#                                             geometry
# 0  MULTIPOLYGON (((37.04215517788462 55.135602100...
# 1  MULTIPOLYGON (((36.975075055426394 55.19086622...
# 2  MULTIPOLYGON (((36.80356979370117 55.451622009...
# 3  POLYGON ((37.436485290527344 55.87957763671875...
# 4  MULTIPOLYGON (((37.54074448059967 55.947839686...

# %%
replacements = {
    'Соколиная Гора': 'Соколиная гора',
    'Марьина Роща': 'Марьина роща',
    'Филевский Парк': 'Филевский парк',
    'Нагатинский Затон': 'Нагатинский затон',

}
mun_geo['mun_district'] = mun_geo['mun_district'].replace(replacements)

# %%
# Добавляем координаты в итоговый датасет
final = pd.merge(result, mun_geo[["mun_district", "geometry"]], on="mun_district", how="left")
final = final.drop("indicator_value", axis=1)
final
# Out:
#                                           mun_district    area     pop_dense  \
# 0    Муниципальные образования города Москвы (столи...     NaN           NaN
# 1                                          Богородское    8.65  12561.502890
# 2                                              Вешняки   10.67  11239.643861
# 3                                  Восточное Измайлово    3.85  19202.337662
# 4                                            Восточный    3.20   4033.125000
# ..                                                 ...     ...           ...
# 144                                          Роговское  178.18     36.356493
# 145                                        Рязановское   40.48    795.825099
# 146                                          Сосенское   66.81   1729.456668
# 147                                     Филимонковское   35.72    454.563270
# 148                                          Щаповское   86.88    153.660221
#
#      pop_work_dense  pop_child_dense    avg_age  trade_per_pers  pers_per_bed  \
# 0               NaN              NaN  41.300748             NaN           NaN
# 1       6906.127168      1996.531792  41.819579        3.661145           NaN
# 2       6399.437676      1560.074977  43.079131             NaN     57.712705
# 3      11500.000000      3111.688312  39.658564             NaN     18.088818
# 4       2331.562500       519.687500  42.835735             NaN    368.742857
# ..              ...              ...        ...             ...           ...
# 144       18.559883         6.240880  43.121179             NaN           NaN
# 145      458.078063       138.166996  41.049666             NaN    495.615385
# 146      986.558898       398.877414  36.707015             NaN   3301.285714
# 147      245.212766        99.972004  38.732463             NaN           NaN
# 148       88.133057        17.414825  45.581798             NaN           NaN
#
#      self_goods_sold  other_goods_sold  org_num  entrep_num  \
# 0                NaN               NaN   448529      613120
# 1         25493879.1         2755713.6     3810        4270
# 2         22482322.9               NaN     3397        1743
# 3         21708295.2         7229392.4     2008        1937
# 4            69276.7               NaN      313         160
# ..               ...               ...      ...         ...
# 144              NaN               NaN      249         120
# 145       41010696.3         9959747.0     1773         598
# 146       67726829.5       112169075.1     8727        7334
# 147         882499.8               NaN     1171         299
# 148       13945371.0               NaN      672         328
#
#                                               geometry
# 0                                                  NaN
# 1    POLYGON ((37.67021179199219 55.838741302490234...
# 2    POLYGON ((37.767520904541016 55.73415374755859...
# 3    POLYGON ((37.799434661865234 55.79318237304687...
# 4    MULTIPOLYGON (((37.79100036621094 56.002658843...
# ..                                                 ...
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
# 148                                                NaN
#
# [149 rows x 13 columns]

# %%
# Все, что осталось - Новая Москва, так что неважно
final[final["geometry"].isna()]
# Out:
#                                           mun_district      area    pop_dense  \
# 0    Муниципальные образования города Москвы (столи...       NaN          NaN
# 130                                         Внуковское   25.5900  2474.091442
# 131                                      Воскресенское   24.8200   818.573731
# 132                                        Вороновское  513.9288    28.393038
# 133                                        Десеновское   53.0000   860.490566
# 134                                           Киевский   60.0900   200.898652
# 135                                         Кленовское  117.7200    47.646959
# 136                                          Кокошкино    9.0000  2424.222222
# 137                                    Краснопахорское  251.5790    51.260240
# 138                                       Марушкинское   50.6300   309.934821
# 139                                Михайлово-Ярцевское   64.6100   143.739359
# 140                                         Московский   40.3900  2765.981679
# 141                                       «Мосрентген»    6.4800  3399.537037
# 142                                    Новофедоровское  150.8000   144.064987
# 143                                       Первомайское  118.9200   208.392196
# 144                                          Роговское  178.1800    36.356493
# 145                                        Рязановское   40.4800   795.825099
# 146                                          Сосенское   66.8100  1729.456668
# 147                                     Филимонковское   35.7200   454.563270
# 148                                          Щаповское   86.8800   153.660221
#
#      pop_work_dense  pop_child_dense    avg_age  trade_per_pers  pers_per_bed  \
# 0               NaN              NaN  41.300748             NaN           NaN
# 130     1258.929269       900.586166  29.221396             NaN   1808.914286
# 131      468.090250       138.879936  41.132598             NaN           NaN
# 132       15.251140         4.973452  42.032689             NaN     72.597015
# 133      501.773585       148.018868  40.226681             NaN           NaN
# 134      106.839740        31.319687  42.547465             NaN           NaN
# 135       25.246347         5.343187  46.244072             NaN           NaN
# 136     1413.222222       295.777778  42.797048             NaN    545.450000
# 137       25.928237        10.418199  41.557305             NaN           NaN
# 138      159.668181        55.046415  42.269245             NaN           NaN
# 139       72.063148        33.802817  38.685797             NaN    265.342857
# 140     1567.888091       576.231741  37.715391      141.865296   3191.942857
# 141     1863.117284       527.006173  41.765400     1302.840569           NaN
# 142       80.676393        31.306366  38.257399             NaN           NaN
# 143      114.505550        43.819374  38.834235             NaN           NaN
# 144       18.559883         6.240880  43.121179             NaN           NaN
# 145      458.078063       138.166996  41.049666             NaN    495.615385
# 146      986.558898       398.877414  36.707015             NaN   3301.285714
# 147      245.212766        99.972004  38.732463             NaN           NaN
# 148       88.133057        17.414825  45.581798             NaN           NaN
#
#      self_goods_sold  other_goods_sold  org_num  entrep_num geometry
# 0                NaN               NaN   448529      613120      NaN
# 130       10803036.1               NaN     3512        1764      NaN
# 131         769202.1               NaN     1044         534      NaN
# 132       14034894.1               NaN      655         309      NaN
# 133       13300968.4               NaN     2517        1217      NaN
# 134         128905.1               NaN      319         131      NaN
# 135              NaN               NaN      255         147      NaN
# 136        2866757.7               NaN      453         135      NaN
# 137        5935721.8               NaN      690         356      NaN
# 138       16251925.3         6761715.3      991         509      NaN
# 139       18521158.3               NaN      359         139      NaN
# 140      206765532.6        43861810.5     6015        4242      NaN
# 141        9131086.6        27494305.1      590         614      NaN
# 142        1703294.8               NaN      912         328      NaN
# 143        8951055.3               NaN     1599        1212      NaN
# 144              NaN               NaN      249         120      NaN
# 145       41010696.3         9959747.0     1773         598      NaN
# 146       67726829.5       112169075.1     8727        7334      NaN
# 147         882499.8               NaN     1171         299      NaN
# 148       13945371.0               NaN      672         328      NaN

# %%
final.to_csv("mun_geo_params.csv")
