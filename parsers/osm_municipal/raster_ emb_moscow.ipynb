# %%
# %%capture
# !pip install osmnx contextily

# %%
import osmnx as ox
import matplotlib.pyplot as plt
import contextily as ctx
from tqdm import tqdm
from shapely.geometry import box
import matplotlib.pyplot as plt
import osmnx as ox
import pandas as pd
import numpy as np
import os

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. Парсер карт

# %%
log_file_path = '/content/drive/MyDrive/masters/geo-embeddings/raster_osm_parser/moscow_maps_log.txt'

def write_to_log(index):
    with open(log_file_path, 'a') as f:  # 'a' - режим добавления в конец файла
        f.write(f"{index}\n")

# %%
# !mkdir moscow_maps
# Out:
# mkdir: cannot create directory ‘moscow_maps’: File exists

# %%
df = pd.read_csv("merged_df_final.csv")

coordinates = list(zip(df['level_0'], df['lat'], df['lng']))

# %%
df[["lat", "lng"]]
# Out:
#              lat        lng
# 0      55.670696  37.750891
# 1      55.673778  37.764671
# 2      55.699097  37.640911
# 3      55.699097  37.640911
# 4      55.783635  37.458337
# ...          ...        ...
# 38593  55.790346  37.469469
# 38594  55.857725  37.615614
# 38595  55.710159  37.469952
# 38596  55.716554  37.457520
# 38597  55.844142  37.495599
#
# [38598 rows x 2 columns]

# %%
def get_fast_map(lat, lon, dist=400, save_path=None):
    # 1. Создаем bounding box
    bbox = ox.utils_geo.bbox_from_point((lat, lon), dist=dist)
    polygon = box(*bbox)

    # 2. Настройка тегов для загрузки
    ox.settings.useful_tags_way =  []

    # 3. Параллельная загрузка зданий и дорог одним запросом (новые версии OSMnx)
    gdf = ox.features_from_polygon(polygon, tags={'building': True,
                                                    'highway': True})

    # Фильтруем здания
    buildings = gdf[gdf['geometry'].notnull() & gdf['building'].notnull()].copy()

    # Фильтруем дороги (исключаем пешеходные дорожки и тропинки для упрощения)
    roads = gdf[gdf['geometry'].notnull() &
            gdf['highway'].notnull() &
            ~gdf['highway'].isin(['footway', 'path', 'pedestrian',
                                  'steps', 'cycleway', 'service',
                                  'unclassified', ])].copy()

    roads = roads[roads.geom_type.isin(['LineString', 'MultiLineString'])]

    # 4. Визуализация
    fig, ax = plt.subplots(figsize=(10, 10))

    # Сначала рисуем дороги (чтобы они были под зданиями)
    if not roads.empty:
        roads.plot(
            ax=ax,
            color='black',
            linewidth=0.7,
            alpha=0.8
        )

    # Затем рисуем здания поверх дорог
    if not buildings.empty:
        buildings.plot(
            ax=ax,
            color='lightgray',
            edgecolor='dimgray',
            linewidth=0.5,
            alpha=0.7
        )

    # 5. Настройка границ
    buffer = dist * 0.000015
    ax.set_xlim([lon - buffer, lon + buffer])
    ax.set_ylim([lat - buffer, lat + buffer])
    ax.axis('off')

    if save_path:
        plt.savefig(save_path, bbox_inches='tight', pad_inches=0, dpi=50)
    plt.close()

    return save_path

# %%
# Пример использования
i = 0
for index, lat, lon in tqdm(coordinates):
    try:
        get_fast_map(lat, lon, save_path=f"moscow_maps/map_{i}.png")
        write_to_log(index)  # Записываем index в лог
        i += 1
    except Exception as e:
        with open(log_file_path, 'a') as f:
            f.write(f"Error processing index {index}: {str(e)}\n")

# %% [markdown]
# ## 2. Получение эмбеддингов

# %%
# %%capture
# !unzip drive/MyDrive/masters/geo-embeddings/raster_osm_parser/ekb/e_m_res.zip -d /content/maps_2
os.makedirs("maps_emb_ekb", exist_ok=True)

# %%
import torch
from torchvision import models, transforms
from PIL import Image

# %%
model = models.efficientnet_b7(pretrained=True)

model.classifier = torch.nn.Identity()

model.eval()

preprocess = transforms.Compose([
    transforms.Resize((200)),
    transforms.CenterCrop(224),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    ),
])

def get_emd(path):
    img = Image.open(path)
    img_tensor = preprocess(img).unsqueeze(0)

    with torch.no_grad():
        embedding = model(img_tensor).squeeze().numpy()
    return embedding

# get_emd("map_6.png")
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B7_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B7_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
for map_name in tqdm(os.listdir("maps_2"), desc="Эмбеддинги изображений"):
    try:
        temp_array = get_emd(f"maps_2/{map_name}")

        parts = map_name.split("_")
        n = parts[1].split(".")[0]

        folder_path = "maps_emb_ekb"
        file_name = f"{n}.npy"
        file_path = os.path.join(folder_path, file_name)

        np.save(file_path, temp_array)

    except Exception as e:
        print(f"Произошла ошибка: {e}")
# Out:
# Эмбеддинги изображений: 100%|██████████| 9117/9117 [51:10<00:00,  2.97it/s]

# %%
# !zip -r ekb_emb.zip /content/maps_emb_ekb
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   adding: content/maps_emb_ekb/1927.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8872.npy (deflated 8%)
#   adding: content/maps_emb_ekb/1210.npy (deflated 8%)
#   adding: content/maps_emb_ekb/6635.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5822.npy (deflated 8%)
#   adding: content/maps_emb_ekb/2694.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4342.npy (deflated 8%)
#   adding: content/maps_emb_ekb/568.npy (deflated 8%)
#   adding: content/maps_emb_ekb/7421.npy (deflated 8%)
#   adding: content/maps_emb_ekb/1958.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8405.npy (deflated 8%)
#   adding: content/maps_emb_ekb/2670.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3932.npy (deflated 8%)
#   adding: content/maps_emb_ekb/7116.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3677.npy (deflated 8%)
#   adding: content/maps_emb_ekb/803.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5305.npy (deflated 8%)
#   adding: content/maps_emb_ekb/6653.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3081.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8838.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3705.npy (deflated 8%)
#   adding: content/maps_emb_ekb/1908.npy (deflated 8%)
#   adding: content/maps_emb_ekb/591.npy (deflated 8%)
#   adding: content/maps_emb_ekb/2633.npy (deflated 8%)
#   adding: content/maps_emb_ekb/6737.npy (deflated 8%)
#   adding: content/maps_emb_ekb/7321.npy (deflated 8%)
#   adding: content/maps_emb_ekb/61.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3808.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4595.npy (deflated 8%)
#   adding: content/maps_emb_ekb/1708.npy (deflated 8%)
#   adding: content/maps_emb_ekb/1461.npy (deflated 8%)
#   adding: content/maps_emb_ekb/2235.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8824.npy (deflated 8%)
#   adding: content/maps_emb_ekb/7703.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5634.npy (deflated 8%)
#   adding: content/maps_emb_ekb/483.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8758.npy (deflated 8%)
#   adding: content/maps_emb_ekb/941.npy (deflated 8%)
#   adding: content/maps_emb_ekb/1206.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5198.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8419.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3732.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3021.npy (deflated 8%)
#   adding: content/maps_emb_ekb/2745.npy (deflated 8%)
#   adding: content/maps_emb_ekb/570.npy (deflated 8%)
#   adding: content/maps_emb_ekb/7396.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4987.npy (deflated 8%)
#   adding: content/maps_emb_ekb/1202.npy (deflated 8%)
#   adding: content/maps_emb_ekb/7056.npy (deflated 8%)
#   adding: content/maps_emb_ekb/2893.npy (deflated 8%)
#   adding: content/maps_emb_ekb/296.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4925.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4324.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8779.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8291.npy (deflated 8%)
#   adding: content/maps_emb_ekb/9009.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4993.npy (deflated 8%)
#   adding: content/maps_emb_ekb/65.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8589.npy (deflated 8%)
#   adding: content/maps_emb_ekb/7132.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5290.npy (deflated 8%)
#   adding: content/maps_emb_ekb/843.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5117.npy (deflated 8%)
#   adding: content/maps_emb_ekb/2021.npy (deflated 8%)
#   adding: content/maps_emb_ekb/2381.npy (deflated 8%)
#   adding: content/maps_emb_ekb/2118.npy (deflated 8%)
#   adding: content/maps_emb_ekb/523.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3871.npy (deflated 8%)
#   adding: content/maps_emb_ekb/1363.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3531.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3954.npy (deflated 7%)
#   adding: content/maps_emb_ekb/6904.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3433.npy (deflated 8%)
#   adding: content/maps_emb_ekb/6392.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8559.npy (deflated 8%)
#   adding: content/maps_emb_ekb/399.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3607.npy (deflated 8%)
#   adding: content/maps_emb_ekb/7150.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5041.npy (deflated 8%)
#   adding: content/maps_emb_ekb/373.npy (deflated 8%)
#   adding: content/maps_emb_ekb/2487.npy (deflated 8%)
#   adding: content/maps_emb_ekb/2613.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5092.npy (deflated 8%)
#   adding: content/maps_emb_ekb/6673.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4544.npy (deflated 8%)
#   adding: content/maps_emb_ekb/2919.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3070.npy (deflated 8%)
#   adding: content/maps_emb_ekb/973.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3580.npy (deflated 8%)
#   adding: content/maps_emb_ekb/147.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5815.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4849.npy (deflated 8%)
#   adding: content/maps_emb_ekb/2078.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5631.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3430.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5149.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4307.npy (deflated 8%)
#   adding: content/maps_emb_ekb/6700.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4216.npy (deflated 8%)
#   adding: content/maps_emb_ekb/1073.npy (deflated 8%)
#   adding: content/maps_emb_ekb/7429.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3996.npy (deflated 8%)
#   adding: content/maps_emb_ekb/6736.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3028.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4913.npy (deflated 8%)
#   adding: content/maps_emb_ekb/
npy (deflated 8%)
#   adding: content/maps_emb_ekb/6454.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8788.npy (deflated 8%)
#   adding: content/maps_emb_ekb/1999.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3094.npy (deflated 8%)
#   adding: content/maps_emb_ekb/717.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8518.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4084.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5229.npy (deflated 8%)
#   adding: content/maps_emb_ekb/6586.npy (deflated 8%)
#   adding: content/maps_emb_ekb/1156.npy (deflated 8%)
#   adding: content/maps_emb_ekb/6989.npy (deflated 8%)
#   adding: content/maps_emb_ekb/7872.npy (deflated 8%)
#   adding: content/maps_emb_ekb/2828.npy (deflated 8%)
#   adding: content/maps_emb_ekb/6153.npy (deflated 8%)
#   adding: content/maps_emb_ekb/986.npy (deflated 8%)
#   adding: content/maps_emb_ekb/366.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3277.npy (deflated 8%)
#   adding: content/maps_emb_ekb/6017.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4632.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4842.npy (deflated 8%)
#   adding: content/maps_emb_ekb/6778.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5159.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3116.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3835.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4129.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5122.npy (deflated 8%)
#   adding: content/maps_emb_ekb/554.npy (deflated 8%)
#   adding: content/maps_emb_ekb/1052.npy (deflated 8%)
#   adding: content/maps_emb_ekb/2169.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8956.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8709.npy (deflated 8%)
#   adding: content/maps_emb_ekb/6782.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4278.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3488.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3049.npy (deflated 8%)
#   adding: content/maps_emb_ekb/1074.npy (deflated 8%)
#   adding: content/maps_emb_ekb/580.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8626.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5694.npy (deflated 8%)
#   adding: content/maps_emb_ekb/7963.npy (deflated 8%)
#   adding: content/maps_emb_ekb/5284.npy (deflated 8%)
#   adding: content/maps_emb_ekb/3693.npy (deflated 8%)
#   adding: content/maps_emb_ekb/8110.npy (deflated 8%)
#   adding: content/maps_emb_ekb/6206.npy (deflated 8%)
#   adding: content/maps_emb_ekb/7155.npy (deflated 8%)
#   adding: content/maps_emb_ekb/6056.npy (deflated 8%)
#   adding: content/maps_emb_ekb/4746.npy (deflated 8%)
#   adding: content/maps_emb_ekb/113.npy (deflated 8%)

# %%
# !cp ekb_emb.zip /content/drive/MyDrive/masters/geo-embeddings/raster_osm_parser/ekb/

# %%
file_path = "maps_emb_ekb/0.npy"

# Load the .npy file
data = np.load(file_path)

# Print the loaded data
print(data)
# Out:
# [ 0.25682458 -0.17701226  0.11119191 ... -0.15363914 -0.16109379
#  -0.12165738]

# %% [markdown]
# ## 3. Эмбеддинги + табличные данные

# %%
# !unzip -q "/content/drive/MyDrive/masters/geo-embeddings/raster_osm_parser/spb/spb_emb.zip" -d "/content/maps_emb_spb"

# %%
spb_data = pd.read_csv("merged_df_final_spb.csv")

# %%
spb_data.head()
# Out:
#    level_0 dealType  roomsCount repairType hasFurniture isApartments  \
# 0        0     sale           1   cosmetic      unknown        false
# 1        1     sale           3         no      unknown        false
# 2        2     sale           2       euro         true        false
# 3        3     sale           2   cosmetic      unknown        false
# 4        4     sale           1   cosmetic      unknown        false
#
#    floorNumber flatType  livingArea windowsViewType  ...  \
# 0            2    rooms        18.6          street  ...
# 1            5    rooms        30.0            yard  ...
# 2           22    rooms        18.7         unknown  ...
# 3           13    rooms        29.0          street  ...
# 4            5    rooms        19.0            yard  ...
#
#    buildings_university  education  food_buy  food_out health  leisure  \
# 0                   1.0         43       100       379     82        9
# 1                   0.0          8        32        19     15        1
# 2                   0.0         19        43        40     32        1
# 3                   0.0          6        15        13     13        0
# 4                   0.0         11        18        17     15        0
#
#   religion  services  shopping  transport
# 0        6        78       251          0
# 1        1        13        33          0
# 2        0        22        52          0
# 3        3         7        11          0
# 4        1         5        12          0
#
# [5 rows x 54 columns]

# %%
# Путь к папке с .npy файлами
folder_path = 'maps_emb_spb/content/maps_emb_spb'

# Шаг 1: Загрузка всех .npy файлов в словарь
embeddings_dict = {}
for file_name in os.listdir(folder_path):
    if file_name.endswith('.npy'):
        # Извлекаем имя файла без расширения
        file_key = os.path.splitext(file_name)[0]
        # Загружаем данные из .npy файла
        embeddings_dict[file_key] = np.load(os.path.join(folder_path, file_name))

# Шаг 2: Сопоставление с датафреймом
spb_data['level_0'] = spb_data['level_0'].astype(str)

# Создаем новую колонку для эмбеддингов
spb_data['embedding'] = spb_data['level_0'].apply(lambda x: embeddings_dict.get(x, None))

# Шаг 3: Проверка результата
missing_embeddings = spb_data[spb_data['embedding'].isnull()]
missing_embeddings
# Out:
#       level_0 dealType  roomsCount repairType hasFurniture isApartments  \
# 24378   24378     sale           2   cosmetic      unknown        false
# 24379   24379     sale           2       euro         true        false
# 24380   24380     sale           2         no      unknown        false
# 24381   24381     sale           2         no      unknown        false
# 24382   24382     sale           2         no      unknown        false
# 24383   24383     sale           2         no      unknown        false
# 24384   24384     sale           2       euro        false        false
# 24385   24385     sale           1       euro      unknown        false
# 24386   24386     sale           4   cosmetic      unknown        false
# 24387   24387     sale           4   cosmetic      unknown        false
#
#        floorNumber flatType  livingArea windowsViewType  ...  education  \
# 24378            1    rooms        31.8            yard  ...         11
# 24379            3    rooms        30.2            yard  ...         12
# 24380            4    rooms        28.3          street  ...         41
# 24381            4    rooms        28.3          street  ...         41
# 24382            1    rooms        39.0            yard  ...         43
# 24383            1    rooms        39.0            yard  ...         43
# 24384            5    rooms        27.6   yardandstreet  ...          7
# 24385           16    rooms        12.4          street  ...         12
# 24386            4    rooms        71.0   yardandstreet  ...         49
# 24387            4    rooms        71.0   yardandstreet  ...         49
#
#        food_buy  food_out  health leisure  religion services  shopping  \
# 24378        16         7       5       0         0        5         8
# 24379        49        44      47       2         0       48       155
# 24380        77       171      86       2         1       60       173
# 24381        77       171      86       2         1       60       173
# 24382        78       237      58      13         8       48       198
# 24383        78       237      58      13         8       48       198
# 24384        43        43      18       2         0       11        74
# 24385        41        21      23       2         2       22        52
# 24386        65       186      75       3         3       56       177
# 24387        65       186      75       3         3       56       177
#
#        transport  embedding
# 24378          0       None
# 24379          0       None
# 24380          0       None
# 24381          0       None
# 24382          0       None
# 24383          0       None
# 24384          0       None
# 24385          0       None
# 24386          0       None
# 24387          0       None
#
# [10 rows x 55 columns]

# %%
spb_data = spb_data[spb_data['embedding'].isnull() != True]
spb_data[spb_data['embedding'].isnull()]
# Out:
# Empty DataFrame
# Columns: [level_0, dealType, roomsCount, repairType, hasFurniture, isApartments, floorNumber, flatType, livingArea, windowsViewType, balconiesCount, kitchenArea, isRecidivist, totalArea, hasLift, buildYear, materialType, lat, lng, distance_to_center, highways_count, undergrounds_count, railways_count, time_to_metro, price, geometry, mun_district, pop_dense, avg_age, self_goods_sold, org_num, entrep_num, buildings_apartments, buildings_service, buildings_office, buildings_school, buildings_commercial, buildings_kindergarten, buildings_retail, buildings_hospital, buildings_industrial, buildings_church, buildings_public, buildings_construction, buildings_university, education, food_buy, food_out, health, leisure, religion, services, shopping, transport, embedding]
# Index: []
#
# [0 rows x 55 columns]

# %%
spb_data.to_csv("merged_df_emb_spb.csv")
